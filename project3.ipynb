# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url='https://way2wise.com/'

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
title=soup.find('title')
print(title)
# Out:
# <title>Homepage - way2wise</title>

# %%
print(title.text)
# Out:
# Homepage - way2wise

# %%
url1='https://way2wise.com/chess/top-15-indian-chess-players-in-2024/'

# %%
page = requests.get(url1)

# %%
soup = BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# ...

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="has-ast-global-color-4-background-color has-background has-fixed-layout"><thead><tr><th class="has-text-align-left" data-align="left">Top 15 Chess Grandmaster, India</th><th class="has-text-align-center" data-align="center">Rating</th></tr></thead><tbody><tr><td class="has-text-align-left" data-align="left">1. <a href="#Viswanathan-Anand">Anand, Viswanathan</a></td><td class="has-text-align-center" data-align="center">2748</td></tr><tr><td class="has-text-align-left" data-align="left">2. <a href="#Dommaraju-Gukesh"></a><a href="#Praggnanandhaa-R">Praggnanandhaa R</a></td><td class="has-text-align-center" data-align="center">2743</td></tr><tr><td class="has-text-align-left" data-align="left">3. <a href="#Vidit,-Santosh-Gujrathi">Vidit, Santosh Gujrathi</a></td><td class="has-text-align-center" data-align="center">2742</td></tr><tr><td class="has-text-align-left" data-align="left">4. <a href="#Erigaisi-Arjun">Erigaisi Arjun</a></td><td class="has-text-align-center" data-a
# ...

# %%
Headings = table.find_all('th')
print(Headings)
# Out:
# [<th class="has-text-align-left" data-align="left">Top 15 Chess Grandmaster, India</th>, <th class="has-text-align-center" data-align="center">Rating</th>]

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# ['Top 15 Chess Grandmaster, India', 'Rating']

# %%
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: [Top 15 Chess Grandmaster, India, Rating]
# Index: []

# %%
rows = table.find_all('tr')
print(rows)
# Out:
# [<tr><th class="has-text-align-left" data-align="left">Top 15 Chess Grandmaster, India</th><th class="has-text-align-center" data-align="center">Rating</th></tr>, <tr><td class="has-text-align-left" data-align="left">1. <a href="#Viswanathan-Anand">Anand, Viswanathan</a></td><td class="has-text-align-center" data-align="center">2748</td></tr>, <tr><td class="has-text-align-left" data-align="left">2. <a href="#Dommaraju-Gukesh"></a><a href="#Praggnanandhaa-R">Praggnanandhaa R</a></td><td class="has-text-align-center" data-align="center">2743</td></tr>, <tr><td class="has-text-align-left" data-align="left">3. <a href="#Vidit,-Santosh-Gujrathi">Vidit, Santosh Gujrathi</a></td><td class="has-text-align-center" data-align="center">2742</td></tr>, <tr><td class="has-text-align-left" data-align="left">4. <a href="#Erigaisi-Arjun">Erigaisi Arjun</a></td><td class="has-text-align-center" data-align="center">2738</td></tr>, <tr><td class="has-text-align-left" data-align="left">5. <a href="#Guk
# ...

# %%
ind=0
for i in rows[1:10]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1
# Out:
# ['1. Anand, Viswanathan', '2748']
# ['2. Praggnanandhaa R', '2743']
# ['3. Vidit, Santosh Gujrathi', '2742']
# ['4. Erigaisi Arjun', '2738']
# ['5. Gukesh D', '2725']
# ['6. Harikrishna, Pentala', '2704']
# ['7. Narayanan. S.L', '2694']
# ['8. Nihal Sarin', '2693']
# ['9. Aravindh Chithambaram', '2662']

# %%
df
# Out:
#   Top 15 Chess Grandmaster, India Rating
# 0           1. Anand, Viswanathan   2748
# 1             2. Praggnanandhaa R   2743
# 2      3. Vidit, Santosh Gujrathi   2742
# 3               4. Erigaisi Arjun   2738
# 4                     5. Gukesh D   2725
# 5         6. Harikrishna, Pentala   2704
# 6               7. Narayanan. S.L   2694
# 7                  8. Nihal Sarin   2693
# 8        9. Aravindh Chithambaram   2662

# %%
df.to_csv("hockey.csv")
